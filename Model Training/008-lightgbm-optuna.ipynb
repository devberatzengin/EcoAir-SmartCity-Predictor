# %%
import pandas as pd
import numpy as np
import os
import lightgbm as lgb
import optuna
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
PATH = "/Users/beratzengin/Desktop/Github/EcoAir SmartCity Predictor/Feature Engineering"
train_df = pd.read_csv(os.path.join(PATH, 'train.csv'))
test_df = pd.read_csv(os.path.join(PATH, 'test.csv'))

target = 'PM10'
features = train_df.select_dtypes(include=[np.number]).columns.tolist()
if target in features:
    features.remove(target)

X_train = train_df[features].fillna(0)
y_train = train_df[target].fillna(train_df[target].mean())
X_test = test_df[features].fillna(0)
y_test = test_df[target].fillna(test_df[target].mean())

# %%
def objective(trial):
    param = {
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'random_state': 42,
        'n_jobs': -1,
        # Optuna'nın deneyeceği aralıklar
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 500, 2000),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 31, 512),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
    }

    model = lgb.LGBMRegressor(**param)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return r2_score(y_test, preds)

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 

print ("Best Params: ",study.best_params)

final_params = study.best_params
final_params['objective'] = 'regression'
final_params['random_state'] = 42
final_params['n_jobs'] = -1

final_model = lgb.LGBMRegressor(**final_params)
final_model.fit(X_train, y_train)
# Out:
# [I 2026-02-28 12:05:26,574] A new study created in memory with name: no-name-34f7dfa6-2167-40d5-8c09-b84998898ca3
# [I 2026-02-28 12:05:59,542] Trial 0 finished with value: 0.88858562559131 and parameters: {'learning_rate': 0.023168635801878723, 'n_estimators': 1111, 'lambda_l1': 0.009034014286186649, 'lambda_l2': 0.06511096674584499, 'num_leaves': 278, 'feature_fraction': 0.7567472428142674, 'bagging_fraction': 0.916127596939109, 'bagging_freq': 4, 'min_child_samples': 73}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:07:08,304] Trial 1 finished with value: 0.8771533488300479 and parameters: {'learning_rate': 0.0937687088748134, 'n_estimators': 1829, 'lambda_l1': 0.034469189749602704, 'lambda_l2': 0.00019487747579652114, 'num_leaves': 419, 'feature_fraction': 0.667175045017825, 'bagging_fraction': 0.7628066519128339, 'bagging_freq': 6, 'min_child_samples': 48}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:07:34,533] Trial 2 finished with value: 0.8879278579628139 and parameters: {'learning_rate': 0.022079650271428622, 'n_estimators': 1869, 'lambda_l1': 0.06814328446245309, 'lambda_l2': 8.74458888093275e-07, 'num_leaves': 139, 'feature_fraction': 0.7399392059712023, 'bagging_fraction': 0.9653562323555372, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:07:44,313] Trial 3 finished with value: 0.8885682616009282 and parameters: {'learning_rate': 0.031131353087159027, 'n_estimators': 1570, 'lambda_l1': 2.4600947885124267, 'lambda_l2': 7.615214649646481e-08, 'num_leaves': 50, 'feature_fraction': 0.802137932540867, 'bagging_fraction': 0.826812270687068, 'bagging_freq': 4, 'min_child_samples': 48}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:09:16,993] Trial 4 finished with value: 0.882247345396465 and parameters: {'learning_rate': 0.041790349364237915, 'n_estimators': 1959, 'lambda_l1': 0.016615125039821523, 'lambda_l2': 0.0004045364809329001, 'num_leaves': 505, 'feature_fraction': 0.6814585653754269, 'bagging_fraction': 0.7416095661403332, 'bagging_freq': 7, 'min_child_samples': 99}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:09:26,360] Trial 5 finished with value: 0.8868474617278477 and parameters: {'learning_rate': 0.03455786577952917, 'n_estimators': 1906, 'lambda_l1': 0.005187426766994976, 'lambda_l2': 0.1165440248014298, 'num_leaves': 43, 'feature_fraction': 0.7910918831326776, 'bagging_fraction': 0.5366956595017289, 'bagging_freq': 1, 'min_child_samples': 45}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:10:09,745] Trial 6 finished with value: 0.8834225741545131 and parameters: {'learning_rate': 0.07811019234986466, 'n_estimators': 1464, 'lambda_l1': 0.059099258780040236, 'lambda_l2': 3.838403146921757e-08, 'num_leaves': 410, 'feature_fraction': 0.6297388523116296, 'bagging_fraction': 0.9905427628478499, 'bagging_freq': 1, 'min_child_samples': 22}. Best is trial 0 with value: 0.88858562559131.
# [I 2026-02-28 12:11:53,870] Trial 7 finished with value: 0.8887240145817998 and parameters: {'learning_rate': 0.01631565205012371, 'n_estimators': 1953, 'lambda_l1': 8.680769795058427e-05, 'lambda_l2': 3.4430579318658617e-06, 'num_leaves': 485, 'feature_fraction': 0.47908540381568665, 'bagging_fraction': 0.7746167031980778, 'bagging_freq': 3, 'min_child_samples': 17}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:12:22,388] Trial 8 finished with value: 0.8814782880518405 and parameters: {'learning_rate': 0.08922786614597913, 'n_estimators': 1049, 'lambda_l1': 1.9006236862437507e-07, 'lambda_l2': 3.63694836346807e-05, 'num_leaves': 267, 'feature_fraction': 0.9387370115652288, 'bagging_fraction': 0.8576486416149661, 'bagging_freq': 3, 'min_child_samples': 64}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:12:36,810] Trial 9 finished with value: 0.884434244384635 and parameters: {'learning_rate': 0.07521059574985925, 'n_estimators': 1489, 'lambda_l1': 2.6189973452184965e-08, 'lambda_l2': 0.0009061647210916636, 'num_leaves': 100, 'feature_fraction': 0.4256610150587907, 'bagging_fraction': 0.8881846395313785, 'bagging_freq': 6, 'min_child_samples': 75}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:12:51,862] Trial 10 finished with value: 0.8843660059382576 and parameters: {'learning_rate': 0.012234349411480328, 'n_estimators': 601, 'lambda_l1': 1.716862178097025e-05, 'lambda_l2': 3.0353765917009836, 'num_leaves': 283, 'feature_fraction': 0.434310486460472, 'bagging_fraction': 0.6003288369135299, 'bagging_freq': 2, 'min_child_samples': 26}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:13:20,102] Trial 11 finished with value: 0.8871738893780814 and parameters: {'learning_rate': 0.010627689845382818, 'n_estimators': 1016, 'lambda_l1': 5.7818841451543535e-05, 'lambda_l2': 0.03278587028606348, 'num_leaves': 231, 'feature_fraction': 0.5452546701657168, 'bagging_fraction': 0.6585501977673314, 'bagging_freq': 3, 'min_child_samples': 84}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:14:00,182] Trial 12 finished with value: 0.8799744574889125 and parameters: {'learning_rate': 0.05678483604149161, 'n_estimators': 1022, 'lambda_l1': 2.0389771524230006e-06, 'lambda_l2': 1.5306661561939892e-06, 'num_leaves': 364, 'feature_fraction': 0.8913521806294946, 'bagging_fraction': 0.4168834900337249, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:14:16,745] Trial 13 finished with value: 0.8875835301702252 and parameters: {'learning_rate': 0.05129022690802794, 'n_estimators': 740, 'lambda_l1': 0.00039750983869545173, 'lambda_l2': 0.03725243603122172, 'num_leaves': 197, 'feature_fraction': 0.5511348033717197, 'bagging_fraction': 0.9067982773138037, 'bagging_freq': 3, 'min_child_samples': 30}. Best is trial 7 with value: 0.8887240145817998.
# [I 2026-02-28 12:15:08,565] Trial 14 finished with value: 0.8899239449658722 and parameters: {'learning_rate': 0.023643245982405643, 'n_estimators': 1239, 'lambda_l1': 0.0005463210400451073, 'lambda_l2': 6.512810945105947, 'num_leaves': 507, 'feature_fraction': 0.5637518768243246, 'bagging_fraction': 0.8006560231427697, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:16:23,050] Trial 15 finished with value: 0.8865740535481901 and parameters: {'learning_rate': 0.051105812031424475, 'n_estimators': 1309, 'lambda_l1': 0.0006243332582004533, 'lambda_l2': 3.3876005320012688, 'num_leaves': 504, 'feature_fraction': 0.5213113104627682, 'bagging_fraction': 0.7806997463245247, 'bagging_freq': 5, 'min_child_samples': 6}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:17:45,391] Trial 16 finished with value: 0.8871064494701386 and parameters: {'learning_rate': 0.021069986738322985, 'n_estimators': 1690, 'lambda_l1': 5.384225685687908e-06, 'lambda_l2': 7.323286021750171e-06, 'num_leaves': 445, 'feature_fraction': 0.588392732080229, 'bagging_fraction': 0.6776784751135216, 'bagging_freq': 5, 'min_child_samples': 18}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:18:37,041] Trial 17 finished with value: 0.8860198772936344 and parameters: {'learning_rate': 0.035170262618414404, 'n_estimators': 1321, 'lambda_l1': 0.00011018868620423446, 'lambda_l2': 0.003335336476483866, 'num_leaves': 349, 'feature_fraction': 0.48344419538135475, 'bagging_fraction': 0.6008795473910398, 'bagging_freq': 2, 'min_child_samples': 35}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:19:16,498] Trial 18 finished with value: 0.8850053275493001 and parameters: {'learning_rate': 0.06451561643033406, 'n_estimators': 799, 'lambda_l1': 1.3393390754691712, 'lambda_l2': 4.316866146348512e-07, 'num_leaves': 466, 'feature_fraction': 0.47665697672980123, 'bagging_fraction': 0.8126492420403253, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:19:53,358] Trial 19 finished with value: 0.8851734231466472 and parameters: {'learning_rate': 0.04435055823336817, 'n_estimators': 1210, 'lambda_l1': 7.223417083506987e-07, 'lambda_l2': 4.7089416879964904e-05, 'num_leaves': 358, 'feature_fraction': 0.6147802815654119, 'bagging_fraction': 0.7350101451707443, 'bagging_freq': 6, 'min_child_samples': 37}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:21:01,619] Trial 20 finished with value: 0.8887801202196384 and parameters: {'learning_rate': 0.017257316518115955, 'n_estimators': 1685, 'lambda_l1': 0.0006068394974574245, 'lambda_l2': 9.607960311090322, 'num_leaves': 465, 'feature_fraction': 0.4133414992561743, 'bagging_fraction': 0.4723584137504576, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:22:16,429] Trial 21 finished with value: 0.8878053684826877 and parameters: {'learning_rate': 0.01963238914180364, 'n_estimators': 1725, 'lambda_l1': 0.0014324541230038592, 'lambda_l2': 8.258239571505477, 'num_leaves': 512, 'feature_fraction': 0.42420609968415096, 'bagging_fraction': 0.42770544094717106, 'bagging_freq': 2, 'min_child_samples': 12}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:23:41,398] Trial 22 finished with value: 0.8852169857747808 and parameters: {'learning_rate': 0.02676165235693915, 'n_estimators': 1688, 'lambda_l1': 6.86217088604556e-05, 'lambda_l2': 0.693663345829956, 'num_leaves': 450, 'feature_fraction': 0.4733108592517377, 'bagging_fraction': 0.49621170523975944, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:24:43,344] Trial 23 finished with value: 0.8887343344405597 and parameters: {'learning_rate': 0.01280118012203545, 'n_estimators': 1445, 'lambda_l1': 0.0017024115683838856, 'lambda_l2': 0.40524547091076385, 'num_leaves': 384, 'feature_fraction': 0.5147161909303507, 'bagging_fraction': 0.658304596252232, 'bagging_freq': 2, 'min_child_samples': 20}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:25:30,833] Trial 24 finished with value: 0.8884671202513108 and parameters: {'learning_rate': 0.01046949233292996, 'n_estimators': 1422, 'lambda_l1': 0.0020341149487076403, 'lambda_l2': 0.557160386316943, 'num_leaves': 395, 'feature_fraction': 0.40664588803466556, 'bagging_fraction': 0.5036730895738207, 'bagging_freq': 1, 'min_child_samples': 25}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:26:29,868] Trial 25 finished with value: 0.8867652879260867 and parameters: {'learning_rate': 0.02789046454595792, 'n_estimators': 1568, 'lambda_l1': 0.3991912240964995, 'lambda_l2': 0.5209428741696386, 'num_leaves': 332, 'feature_fraction': 0.578202399835494, 'bagging_fraction': 0.6141409756156192, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:27:36,224] Trial 26 finished with value: 0.8846430777406622 and parameters: {'learning_rate': 0.03955907873022423, 'n_estimators': 1383, 'lambda_l1': 1.1716339459097468e-05, 'lambda_l2': 0.006009938587089967, 'num_leaves': 434, 'feature_fraction': 0.5123373945263273, 'bagging_fraction': 0.6925774718516233, 'bagging_freq': 2, 'min_child_samples': 36}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:28:16,298] Trial 27 finished with value: 0.8895116238803097 and parameters: {'learning_rate': 0.01694220998552685, 'n_estimators': 885, 'lambda_l1': 0.30508170469439416, 'lambda_l2': 8.362398533809163, 'num_leaves': 465, 'feature_fraction': 0.6487855271467605, 'bagging_fraction': 0.5255275085695529, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:28:52,591] Trial 28 finished with value: 0.8877674304774832 and parameters: {'learning_rate': 0.029190048943290307, 'n_estimators': 912, 'lambda_l1': 8.116756716885593, 'lambda_l2': 7.772444152781018, 'num_leaves': 471, 'feature_fraction': 0.6383395725035168, 'bagging_fraction': 0.4724411862700301, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:29:23,873] Trial 29 finished with value: 0.8880259274573029 and parameters: {'learning_rate': 0.023022562022174613, 'n_estimators': 1156, 'lambda_l1': 0.13958581313815172, 'lambda_l2': 1.6817632741100401, 'num_leaves': 307, 'feature_fraction': 0.7190114580600929, 'bagging_fraction': 0.5484580434910508, 'bagging_freq': 5, 'min_child_samples': 31}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:29:49,264] Trial 30 finished with value: 0.8871094895586508 and parameters: {'learning_rate': 0.017394266083386872, 'n_estimators': 545, 'lambda_l1': 0.010144166211943629, 'lambda_l2': 0.13171696520714726, 'num_leaves': 472, 'feature_fraction': 0.7954693020435852, 'bagging_fraction': 0.46831538926914024, 'bagging_freq': 4, 'min_child_samples': 56}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:30:57,899] Trial 31 finished with value: 0.8891742746421909 and parameters: {'learning_rate': 0.015584263888118713, 'n_estimators': 1564, 'lambda_l1': 0.004323884684117411, 'lambda_l2': 9.349719355363979, 'num_leaves': 392, 'feature_fraction': 0.5747275396421286, 'bagging_fraction': 0.5587251433897487, 'bagging_freq': 1, 'min_child_samples': 21}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:31:28,290] Trial 32 finished with value: 0.8891229130744942 and parameters: {'learning_rate': 0.01696901749236766, 'n_estimators': 898, 'lambda_l1': 0.005818468103298457, 'lambda_l2': 7.466129337644046, 'num_leaves': 423, 'feature_fraction': 0.6513761218308982, 'bagging_fraction': 0.5647790222341756, 'bagging_freq': 1, 'min_child_samples': 13}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:31:57,126] Trial 33 finished with value: 0.8877435612927663 and parameters: {'learning_rate': 0.024467161437148895, 'n_estimators': 869, 'lambda_l1': 0.27391859493720966, 'lambda_l2': 1.3255037558204907, 'num_leaves': 420, 'feature_fraction': 0.6643902908503901, 'bagging_fraction': 0.5595394658497425, 'bagging_freq': 1, 'min_child_samples': 15}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:32:23,877] Trial 34 finished with value: 0.8868995282402349 and parameters: {'learning_rate': 0.033685865389139244, 'n_estimators': 668, 'lambda_l1': 0.038933579454396385, 'lambda_l2': 0.20391330855991233, 'num_leaves': 394, 'feature_fraction': 0.5948602470470288, 'bagging_fraction': 0.5835834019064624, 'bagging_freq': 6, 'min_child_samples': 41}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:32:58,479] Trial 35 finished with value: 0.8880821845080176 and parameters: {'learning_rate': 0.024544770717471538, 'n_estimators': 929, 'lambda_l1': 0.0044904405397744145, 'lambda_l2': 2.8769016643748646, 'num_leaves': 428, 'feature_fraction': 0.7075840841151588, 'bagging_fraction': 0.6370762283136157, 'bagging_freq': 1, 'min_child_samples': 25}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:33:49,439] Trial 36 finished with value: 0.8869139221500795 and parameters: {'learning_rate': 0.014588100734403912, 'n_estimators': 1106, 'lambda_l1': 0.6955379043346577, 'lambda_l2': 0.01098563418705086, 'num_leaves': 485, 'feature_fraction': 0.7585124018038575, 'bagging_fraction': 0.514956481198149, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:34:31,861] Trial 37 finished with value: 0.8870055652119856 and parameters: {'learning_rate': 0.036582814765068736, 'n_estimators': 1233, 'lambda_l1': 0.01344562998012823, 'lambda_l2': 1.9645047466387844, 'num_leaves': 379, 'feature_fraction': 0.6610371654744105, 'bagging_fraction': 0.7223780463111948, 'bagging_freq': 1, 'min_child_samples': 21}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:34:58,769] Trial 38 finished with value: 0.8836539005347807 and parameters: {'learning_rate': 0.04430957055605465, 'n_estimators': 785, 'lambda_l1': 4.9866858247541, 'lambda_l2': 0.20808689466135855, 'num_leaves': 326, 'feature_fraction': 0.8504728189366424, 'bagging_fraction': 0.563863462956966, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:36:19,679] Trial 39 finished with value: 0.8844650460934659 and parameters: {'learning_rate': 0.031473329873949685, 'n_estimators': 1799, 'lambda_l1': 0.06928664386165699, 'lambda_l2': 9.83168323126351, 'num_leaves': 418, 'feature_fraction': 0.7433870761854517, 'bagging_fraction': 0.4380873428419854, 'bagging_freq': 5, 'min_child_samples': 99}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:37:22,782] Trial 40 finished with value: 0.8812844572706138 and parameters: {'learning_rate': 0.09856904250138948, 'n_estimators': 1558, 'lambda_l1': 0.01843173440209538, 'lambda_l2': 0.06676268518305278, 'num_leaves': 500, 'feature_fraction': 0.689404651227706, 'bagging_fraction': 0.8096180988079653, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:38:30,199] Trial 41 finished with value: 0.8886933663111715 and parameters: {'learning_rate': 0.019868433092063466, 'n_estimators': 1636, 'lambda_l1': 0.0002061796024354178, 'lambda_l2': 9.913109740701605, 'num_leaves': 470, 'feature_fraction': 0.6286524796523123, 'bagging_fraction': 0.46327150353618907, 'bagging_freq': 1, 'min_child_samples': 8}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:39:56,074] Trial 42 finished with value: 0.8889696878435442 and parameters: {'learning_rate': 0.01687467520431113, 'n_estimators': 1841, 'lambda_l1': 0.004942176351860518, 'lambda_l2': 1.072189388390359, 'num_leaves': 448, 'feature_fraction': 0.5771462218310309, 'bagging_fraction': 0.95098127729783, 'bagging_freq': 1, 'min_child_samples': 17}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:41:20,456] Trial 43 finished with value: 0.8890614154476599 and parameters: {'learning_rate': 0.01805350037367437, 'n_estimators': 1801, 'lambda_l1': 0.0034683650754740703, 'lambda_l2': 1.1389852878623496, 'num_leaves': 446, 'feature_fraction': 0.5522437176270609, 'bagging_fraction': 0.9414526643608524, 'bagging_freq': 1, 'min_child_samples': 16}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:42:00,423] Trial 44 finished with value: 0.8897837795979466 and parameters: {'learning_rate': 0.021664701111357595, 'n_estimators': 955, 'lambda_l1': 0.13167458773049723, 'lambda_l2': 4.495416013794331, 'num_leaves': 400, 'feature_fraction': 0.5484537394184072, 'bagging_fraction': 0.9392074121824688, 'bagging_freq': 1, 'min_child_samples': 29}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:42:31,168] Trial 45 finished with value: 0.8891474988350555 and parameters: {'learning_rate': 0.027649790320556426, 'n_estimators': 956, 'lambda_l1': 0.1734976041049684, 'lambda_l2': 3.6130769876136877, 'num_leaves': 413, 'feature_fraction': 0.6484068336564378, 'bagging_fraction': 0.8355660383996711, 'bagging_freq': 1, 'min_child_samples': 24}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:43:08,253] Trial 46 finished with value: 0.889351025443385 and parameters: {'learning_rate': 0.02651217831541669, 'n_estimators': 1084, 'lambda_l1': 1.8167805035503657, 'lambda_l2': 2.9059144242441826, 'num_leaves': 405, 'feature_fraction': 0.6098427721455897, 'bagging_fraction': 0.8622817305674183, 'bagging_freq': 3, 'min_child_samples': 29}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:43:31,610] Trial 47 finished with value: 0.8891546760921429 and parameters: {'learning_rate': 0.02342646748145244, 'n_estimators': 1086, 'lambda_l1': 1.4521555426281547, 'lambda_l2': 0.30063693950259324, 'num_leaves': 244, 'feature_fraction': 0.6075582188903262, 'bagging_fraction': 0.9952282540789685, 'bagging_freq': 3, 'min_child_samples': 30}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:43:55,718] Trial 48 finished with value: 0.8888574189818814 and parameters: {'learning_rate': 0.031236654491580564, 'n_estimators': 1174, 'lambda_l1': 3.065209173789662, 'lambda_l2': 0.02674999662495561, 'num_leaves': 173, 'feature_fraction': 0.545048977081541, 'bagging_fraction': 0.8845497768216312, 'bagging_freq': 4, 'min_child_samples': 43}. Best is trial 14 with value: 0.8899239449658722.
# [I 2026-02-28 12:44:11,096] Trial 49 finished with value: 0.8872294828037832 and parameters: {'learning_rate': 0.03935956776443997, 'n_estimators': 1305, 'lambda_l1': 0.7508082217423077, 'lambda_l2': 0.0011317812947935165, 'num_leaves': 94, 'feature_fraction': 0.5711772753093123, 'bagging_fraction': 0.8607884231235584, 'bagging_freq': 4, 'min_child_samples': 28}. Best is trial 14 with value: 0.8899239449658722.
# Best Params:  {'learning_rate': 0.023643245982405643, 'n_estimators': 1239, 'lambda_l1': 0.0005463210400451073, 'lambda_l2': 6.512810945105947, 'num_leaves': 507, 'feature_fraction': 0.5637518768243246, 'bagging_fraction': 0.8006560231427697, 'bagging_freq': 5, 'min_child_samples': 5}
# LGBMRegressor(bagging_fraction=0.8006560231427697, bagging_freq=5,
#               feature_fraction=0.5637518768243246,
#               lambda_l1=0.0005463210400451073, lambda_l2=6.512810945105947,
#               learning_rate=0.023643245982405643, min_child_samples=5,
#               n_estimators=1239, n_jobs=-1, num_leaves=507,
#               objective='regression', random_state=42)

# %%
from sklearn.metrics import mean_absolute_error
import csv
from datetime import datetime

y_pred = final_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"\n--- OPTIMIZED LIGHTGBM SONUÇLARI ---")
print(f"R2 SCORE: {r2:.4f}")
print(f"MAE: {mae:.4f}")

# Deftere işle
log_path = os.path.join(PATH, 'model_performances.csv')
with open(log_path, 'a', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([
        datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        '008',
        'LightGBM (Optuna Tuned)',
        mae,
        np.sqrt(((y_test - y_pred) ** 2).mean()),
        r2,
        f'all_numeric_{len(features)}_cols',
        'Tuned with 50 trials'
    ])
# Out:
# --- OPTIMIZED LIGHTGBM SONUÇLARI ---
# R2 SCORE: 0.8899
# MAE: 6.6125
