# %%
import pandas as pd
import numpy as np
import os
import re

# %%
# --- PATH CONFIGURATION ---
BASE_PATH = "/Users/beratzengin/Desktop/Github/EcoAir SmartCity Predictor/Data"
TRAFFIC_SOURCE_DIR = os.path.join(BASE_PATH, "--traffic")
STATIONS_CSV = os.path.join(BASE_PATH, "stations_info.csv")

# %%
def parse_coords(location_str):
    match = re.search(r'\((.*?)\)', location_str)
    if match:
        coords = match.group(1).split(' ')
        return float(coords[1]), float(coords[0]) # Returns (lat, lon)
    return None, None

# %%
# Load station metadata
stations_df = pd.read_csv(STATIONS_CSV)

# List all monthly traffic files (e.g., january_01.csv)
traffic_files = sorted([f for f in os.listdir(TRAFFIC_SOURCE_DIR) if f.endswith('.csv')])

# %%
for t_file in traffic_files:
    print(f"🚜 Processing Source File: {t_file}")
    file_path = os.path.join(TRAFFIC_SOURCE_DIR, t_file)
    
    # Load the big monthly dataset
    df_month = pd.read_csv(file_path)
    df_month.columns = [c.upper() for c in df_month.columns] # Standardize headers
    
    # Extract month number from filename (assuming format like 'january_01.csv')
    month_id = re.search(r'(\d+)', t_file).group(1)
    
    for _, s_row in stations_df.iterrows():
        s_name = s_row['Name'].replace(" ", "_").replace("/", "-")
        s_lat, s_lon = parse_coords(s_row['Location'])
        target_dir = os.path.join(BASE_PATH, s_name)
        
        # Geofencing: Filter sensors within ~2km radius (approx 0.02 degrees)
        local_mask = (np.abs(df_month['LATITUDE'] - s_lat) < 0.02) & \
                     (np.abs(df_month['LONGITUDE'] - s_lon) < 0.02)
        
        local_traffic = df_month[local_mask].copy()
        
        if not local_traffic.empty:
            # 1. Convert to datetime
            local_traffic['DATE_TIME'] = pd.to_datetime(local_traffic['DATE_TIME'])
            
            # 2. Hourly Downsampling/Aggregation
            # Average speed and total number of vehicles per hour
            hourly_traffic = local_traffic.groupby(local_traffic['DATE_TIME'].dt.floor('h')).agg({
                'AVERAGE_SPEED': 'mean',
                'NUMBER_OF_VEHICLES': 'sum'
            }).reset_index()
            
            # Rename columns for clarity
            hourly_traffic.columns = ['date', 'avg_speed', 'total_vehicles']
            
            # 3. Save as localized monthly file
            output_path = os.path.join(target_dir, f"traffic_{month_id}_2024.csv")
            hourly_traffic.to_csv(output_path, index=False)
            
            print(f"{s_name}: Saved {len(hourly_traffic)} hours for month {month_id}")
        else:
            print(f"{s_name}: No traffic sensors found nearby in {t_file}")
# Out:
# 🚜 Processing Source File: april_04.csv
# Maslak: Saved 684 hours for month 04
# Esenler: Saved 684 hours for month 04
# Yenibosna: Saved 691 hours for month 04
# Beylikdüzü: No traffic sensors found nearby in april_04.csv
# Ümraniye_1: Saved 701 hours for month 04
# Aksaray: Saved 681 hours for month 04
# Mobil: Saved 683 hours for month 04
# Beşiktaş: Saved 685 hours for month 04
# Kadıköy: Saved 683 hours for month 04
# Sultangazi_1: Saved 686 hours for month 04
# Avcılar: Saved 686 hours for month 04
# Sultangazi_3: Saved 684 hours for month 04
# Üsküdar_1: Saved 689 hours for month 04
# Alibeyköy: Saved 683 hours for month 04
# Selimiye: Saved 689 hours for month 04
# D-100_: Saved 686 hours for month 04
# Kağıthane_1: Saved 685 hours for month 04
# Kandilli_1: Saved 681 hours for month 04
# Kartal: Saved 689 hours for month 04
# Çatladıkapı: Saved 681 hours for month 04
# Sultangazi_2: Saved 687 hours for month 04
# Bağcılar: Saved 686 hours for month 04
# Kumköy: Saved 674 hours for month 04
# Sarıyer: Saved 680 hours for month 04
# Büyükada: No traffic sensors found nearby in april_04.csv
# Sancaktepe: Saved 685 hours for month 04
# Arnavutköy: Saved 679 hours for month 04
# Tuzla: Saved 684 hours for month 04
# 🚜 Processing Source File: august_08.csv
# Maslak: Saved 721 hours for month 08
# Esenler: Saved 721 hours for month 08
# Yenibosna: Saved 721 hours for month 08
# Beylikdüzü: No traffic sensors found nearby in august_08.csv
# Ümraniye_1: Saved 721 hours for month 08
# Aksaray: Saved 721 hours for month 08
# Mobil: Saved 721 hours for month 08
# Beşiktaş: Saved 721 hours for month 08
# Kadıköy: Saved 721 hours for month 08
# Sultangazi_1: Saved 721 hours for month 08
# Avcılar: Saved 721 hours for month 08
# Sultangazi_3: Saved 721 hours for month 08
# Üsküdar_1: Saved 721 hours for month 08
# Alibeyköy: Saved 721 hours for month 08
# Selimiye: Saved 721 hours for month 08
# D-100_: Saved 721 hours for month 08
# Kağıthane_1: Saved 721 hours for month 08
# Kandilli_1: Saved 721 hours for month 08
# Kartal: Saved 721 hours for month 08
# Çatladıkapı: Saved 721 hours for month 08
# Sultangazi_2: Saved 721 hours for month 08
# Bağcılar: Saved 721 hours for month 08
# Kumköy: Saved 715 hours for month 08
# Sarıyer: Saved 721 hours for month 08
# Büyükada: No traffic sensors found nearby in august_08.csv
# Sancaktepe: Saved 721 hours for month 08
# Arnavutköy: Saved 721 hours for month 08
# Tuzla: Saved 721 hours for month 08
# 🚜 Processing Source File: december_12.csv
# Maslak: Saved 533 hours for month 12
# Esenler: Saved 533 hours for month 12
# Yenibosna: Saved 533 hours for month 12
# Beylikdüzü: No traffic sensors found nearby in december_12.csv
# Ümraniye_1: Saved 533 hours for month 12
# Aksaray: Saved 533 hours for month 12
# Mobil: Saved 533 hours for month 12
# Beşiktaş: Saved 533 hours for month 12
# Kadıköy: Saved 533 hours for month 12
# Sultangazi_1: Saved 533 hours for month 12
# Avcılar: Saved 533 hours for month 12
# Sultangazi_3: Saved 533 hours for month 12
# Üsküdar_1: Saved 533 hours for month 12
# Alibeyköy: Saved 533 hours for month 12
# Selimiye: Saved 533 hours for month 12
# D-100_: Saved 533 hours for month 12
# Kağıthane_1: Saved 533 hours for month 12
# Kandilli_1: Saved 533 hours for month 12
# Kartal: Saved 533 hours for month 12
# Çatladıkapı: Saved 533 hours for month 12
# Sultangazi_2: Saved 533 hours for month 12
# Bağcılar: Saved 533 hours for month 12
# Kumköy: Saved 528 hours for month 12
# Sarıyer: Saved 533 hours for month 12
# Büyükada: No traffic sensors found nearby in december_12.csv
# Sancaktepe: Saved 533 hours for month 12
# Arnavutköy: Saved 533 hours for month 12
# Tuzla: Saved 533 hours for month 12
# 🚜 Processing Source File: february_02.csv
# Maslak: Saved 672 hours for month 02
# Esenler: Saved 672 hours for month 02
# Yenibosna: Saved 673 hours for month 02
# Beylikdüzü: No traffic sensors found nearby in february_02.csv
# Ümraniye_1: Saved 673 hours for month 02
# Aksaray: Saved 672 hours for month 02
# Mobil: Saved 672 hours for month 02
# Beşiktaş: Saved 672 hours for month 02
# Kadıköy: Saved 672 hours for month 02
# Sultangazi_1: Saved 672 hours for month 02
# Avcılar: Saved 672 hours for month 02
# Sultangazi_3: Saved 672 hours for month 02
# Üsküdar_1: Saved 672 hours for month 02
# Alibeyköy: Saved 672 hours for month 02
# Selimiye: Saved 672 hours for month 02
# D-100_: Saved 672 hours for month 02
# Kağıthane_1: Saved 672 hours for month 02
# Kandilli_1: Saved 673 hours for month 02
# Kartal: Saved 672 hours for month 02
# Çatladıkapı: Saved 672 hours for month 02
# Sultangazi_2: Saved 672 hours for month 02
# Bağcılar: Saved 672 hours for month 02
# Kumköy: Saved 660 hours for month 02
# Sarıyer: Saved 672 hours for month 02
# Büyükada: No traffic sensors found nearby in february_02.csv
# Sancaktepe: Saved 672 hours for month 02
# Arnavutköy: Saved 672 hours for month 02
# Tuzla: Saved 672 hours for month 02
# 🚜 Processing Source File: january_01.csv
# Maslak: Saved 406 hours for month 01
# Esenler: Saved 406 hours for month 01
# Yenibosna: Saved 406 hours for month 01
# Beylikdüzü: No traffic sensors found nearby in january_01.csv
# Ümraniye_1: Saved 406 hours for month 01
# Aksaray: Saved 406 hours for month 01
# Mobil: Saved 406 hours for month 01
# Beşiktaş: Saved 406 hours for month 01
# Kadıköy: Saved 406 hours for month 01
# Sultangazi_1: Saved 406 hours for month 01
# Avcılar: Saved 406 hours for month 01
# Sultangazi_3: Saved 406 hours for month 01
# Üsküdar_1: Saved 406 hours for month 01
# Alibeyköy: Saved 406 hours for month 01
# Selimiye: Saved 406 hours for month 01
# D-100_: Saved 406 hours for month 01
# Kağıthane_1: Saved 406 hours for month 01
# Kandilli_1: Saved 406 hours for month 01
# Kartal: Saved 406 hours for month 01
# Çatladıkapı: Saved 406 hours for month 01
# Sultangazi_2: Saved 406 hours for month 01
# Bağcılar: Saved 406 hours for month 01
# Kumköy: Saved 401 hours for month 01
# Sarıyer: Saved 406 hours for month 01
# Büyükada: No traffic sensors found nearby in january_01.csv
# Sancaktepe: Saved 406 hours for month 01
# Arnavutköy: Saved 406 hours for month 01
# Tuzla: Saved 406 hours for month 01
# 🚜 Processing Source File: july_07.csv
# Maslak: Saved 744 hours for month 07
# Esenler: Saved 744 hours for month 07
# Yenibosna: Saved 744 hours for month 07
# Beylikdüzü: No traffic sensors found nearby in july_07.csv
# Ümraniye_1: Saved 744 hours for month 07
# Aksaray: Saved 744 hours for month 07
# Mobil: Saved 744 hours for month 07
# Beşiktaş: Saved 744 hours for month 07
# Kadıköy: Saved 744 hours for month 07
# Sultangazi_1: Saved 744 hours for month 07
# Avcılar: Saved 744 hours for month 07
# Sultangazi_3: Saved 744 hours for month 07
# Üsküdar_1: Saved 744 hours for month 07
# Alibeyköy: Saved 744 hours for month 07
# Selimiye: Saved 744 hours for month 07
# D-100_: Saved 744 hours for month 07
# Kağıthane_1: Saved 744 hours for month 07
# Kandilli_1: Saved 744 hours for month 07
# Kartal: Saved 744 hours for month 07
# Çatladıkapı: Saved 744 hours for month 07
# Sultangazi_2: Saved 744 hours for month 07
# Bağcılar: Saved 744 hours for month 07
# Kumköy: Saved 739 hours for month 07
# Sarıyer: Saved 744 hours for month 07
# Büyükada: No traffic sensors found nearby in july_07.csv
# Sancaktepe: Saved 744 hours for month 07
# Arnavutköy: Saved 744 hours for month 07
# Tuzla: Saved 744 hours for month 07
# 🚜 Processing Source File: june_06.csv
# Maslak: Saved 648 hours for month 06
# Esenler: Saved 648 hours for month 06
# Yenibosna: Saved 648 hours for month 06
# Beylikdüzü: No traffic sensors found nearby in june_06.csv
# Ümraniye_1: Saved 648 hours for month 06
# Aksaray: Saved 648 hours for month 06
# Mobil: Saved 648 hours for month 06
# Beşiktaş: Saved 648 hours for month 06
# Kadıköy: Saved 648 hours for month 06
# Sultangazi_1: Saved 648 hours for month 06
# Avcılar: Saved 648 hours for month 06
# Sultangazi_3: Saved 648 hours for month 06
# Üsküdar_1: Saved 648 hours for month 06
# Alibeyköy: Saved 648 hours for month 06
# Selimiye: Saved 648 hours for month 06
# D-100_: Saved 648 hours for month 06
# Kağıthane_1: Saved 648 hours for month 06
# Kandilli_1: Saved 648 hours for month 06
# Kartal: Saved 648 hours for month 06
# Çatladıkapı: Saved 648 hours for month 06
# Sultangazi_2: Saved 648 hours for month 06
# Bağcılar: Saved 648 hours for month 06
# Kumköy: Saved 644 hours for month 06
# Sarıyer: Saved 648 hours for month 06
# Büyükada: No traffic sensors found nearby in june_06.csv
# Sancaktepe: Saved 648 hours for month 06
# Arnavutköy: Saved 648 hours for month 06
# Tuzla: Saved 648 hours for month 06
# 🚜 Processing Source File: march_03.csv
# Maslak: Saved 733 hours for month 03
# Esenler: Saved 733 hours for month 03
# Yenibosna: Saved 733 hours for month 03
# Beylikdüzü: No traffic sensors found nearby in march_03.csv
# Ümraniye_1: Saved 733 hours for month 03
# Aksaray: Saved 733 hours for month 03
# Mobil: Saved 733 hours for month 03
# Beşiktaş: Saved 733 hours for month 03
# Kadıköy: Saved 733 hours for month 03
# Sultangazi_1: Saved 733 hours for month 03
# Avcılar: Saved 733 hours for month 03
# Sultangazi_3: Saved 733 hours for month 03
# Üsküdar_1: Saved 733 hours for month 03
# Alibeyköy: Saved 733 hours for month 03
# Selimiye: Saved 733 hours for month 03
# D-100_: Saved 733 hours for month 03
# Kağıthane_1: Saved 733 hours for month 03
# Kandilli_1: Saved 733 hours for month 03
# Kartal: Saved 733 hours for month 03
# Çatladıkapı: Saved 733 hours for month 03
# Sultangazi_2: Saved 733 hours for month 03
# Bağcılar: Saved 733 hours for month 03
# Kumköy: Saved 727 hours for month 03
# Sarıyer: Saved 733 hours for month 03
# Büyükada: No traffic sensors found nearby in march_03.csv
# Sancaktepe: Saved 733 hours for month 03
# Arnavutköy: Saved 733 hours for month 03
# Tuzla: Saved 733 hours for month 03
# 🚜 Processing Source File: may_05.csv
# Maslak: Saved 695 hours for month 05
# Esenler: Saved 695 hours for month 05
# Yenibosna: Saved 696 hours for month 05
# Beylikdüzü: No traffic sensors found nearby in may_05.csv
# Ümraniye_1: Saved 696 hours for month 05
# Aksaray: Saved 695 hours for month 05
# Mobil: Saved 695 hours for month 05
# Beşiktaş: Saved 695 hours for month 05
# Kadıköy: Saved 695 hours for month 05
# Sultangazi_1: Saved 695 hours for month 05
# Avcılar: Saved 695 hours for month 05
# Sultangazi_3: Saved 695 hours for month 05
# Üsküdar_1: Saved 695 hours for month 05
# Alibeyköy: Saved 695 hours for month 05
# Selimiye: Saved 695 hours for month 05
# D-100_: Saved 695 hours for month 05
# Kağıthane_1: Saved 695 hours for month 05
# Kandilli_1: Saved 696 hours for month 05
# Kartal: Saved 695 hours for month 05
# Çatladıkapı: Saved 695 hours for month 05
# Sultangazi_2: Saved 695 hours for month 05
# Bağcılar: Saved 695 hours for month 05
# Kumköy: Saved 694 hours for month 05
# Sarıyer: Saved 695 hours for month 05
# Büyükada: No traffic sensors found nearby in may_05.csv
# Sancaktepe: Saved 695 hours for month 05
# Arnavutköy: Saved 695 hours for month 05
# Tuzla: Saved 695 hours for month 05
# 🚜 Processing Source File: november_11.csv
# Maslak: Saved 720 hours for month 11
# Esenler: Saved 720 hours for month 11
# Yenibosna: Saved 720 hours for month 11
# Beylikdüzü: No traffic sensors found nearby in november_11.csv
# Ümraniye_1: Saved 720 hours for month 11
# Aksaray: Saved 720 hours for month 11
# Mobil: Saved 720 hours for month 11
# Beşiktaş: Saved 720 hours for month 11
# Kadıköy: Saved 720 hours for month 11
# Sultangazi_1: Saved 720 hours for month 11
# Avcılar: Saved 720 hours for month 11
# Sultangazi_3: Saved 720 hours for month 11
# Üsküdar_1: Saved 720 hours for month 11
# Alibeyköy: Saved 720 hours for month 11
# Selimiye: Saved 720 hours for month 11
# D-100_: Saved 720 hours for month 11
# Kağıthane_1: Saved 720 hours for month 11
# Kandilli_1: Saved 720 hours for month 11
# Kartal: Saved 720 hours for month 11
# Çatladıkapı: Saved 720 hours for month 11
# Sultangazi_2: Saved 720 hours for month 11
# Bağcılar: Saved 720 hours for month 11
# Kumköy: Saved 709 hours for month 11
# Sarıyer: Saved 720 hours for month 11
# Büyükada: No traffic sensors found nearby in november_11.csv
# Sancaktepe: Saved 720 hours for month 11
# Arnavutköy: Saved 720 hours for month 11
# Tuzla: Saved 720 hours for month 11
# 🚜 Processing Source File: october_10.csv
# Maslak: Saved 743 hours for month 10
# Esenler: Saved 743 hours for month 10
# Yenibosna: Saved 744 hours for month 10
# Beylikdüzü: No traffic sensors found nearby in october_10.csv
# Ümraniye_1: Saved 743 hours for month 10
# Aksaray: Saved 743 hours for month 10
# Mobil: Saved 743 hours for month 10
# Beşiktaş: Saved 743 hours for month 10
# Kadıköy: Saved 743 hours for month 10
# Sultangazi_1: Saved 743 hours for month 10
# Avcılar: Saved 743 hours for month 10
# Sultangazi_3: Saved 743 hours for month 10
# Üsküdar_1: Saved 743 hours for month 10
# Alibeyköy: Saved 743 hours for month 10
# Selimiye: Saved 743 hours for month 10
# D-100_: Saved 743 hours for month 10
# Kağıthane_1: Saved 743 hours for month 10
# Kandilli_1: Saved 743 hours for month 10
# Kartal: Saved 743 hours for month 10
# Çatladıkapı: Saved 743 hours for month 10
# Sultangazi_2: Saved 743 hours for month 10
# Bağcılar: Saved 743 hours for month 10
# Kumköy: Saved 737 hours for month 10
# Sarıyer: Saved 743 hours for month 10
# Büyükada: No traffic sensors found nearby in october_10.csv
# Sancaktepe: Saved 743 hours for month 10
# Arnavutköy: Saved 743 hours for month 10
# Tuzla: Saved 743 hours for month 10
# 🚜 Processing Source File: september_09.csv
# Maslak: Saved 720 hours for month 09
# Esenler: Saved 720 hours for month 09
# Yenibosna: Saved 720 hours for month 09
# Beylikdüzü: No traffic sensors found nearby in september_09.csv
# Ümraniye_1: Saved 720 hours for month 09
# Aksaray: Saved 720 hours for month 09
# Mobil: Saved 720 hours for month 09
# Beşiktaş: Saved 720 hours for month 09
# Kadıköy: Saved 720 hours for month 09
# Sultangazi_1: Saved 720 hours for month 09
# Avcılar: Saved 720 hours for month 09
# Sultangazi_3: Saved 720 hours for month 09
# Üsküdar_1: Saved 720 hours for month 09
# Alibeyköy: Saved 720 hours for month 09
# Selimiye: Saved 720 hours for month 09
# D-100_: Saved 720 hours for month 09
# Kağıthane_1: Saved 720 hours for month 09
# Kandilli_1: Saved 720 hours for month 09
# Kartal: Saved 720 hours for month 09
# Çatladıkapı: Saved 720 hours for month 09
# Sultangazi_2: Saved 720 hours for month 09
# Bağcılar: Saved 720 hours for month 09
# Kumköy: Saved 716 hours for month 09
# Sarıyer: Saved 720 hours for month 09
# Büyükada: No traffic sensors found nearby in september_09.csv
# Sancaktepe: Saved 720 hours for month 09
# Arnavutköy: Saved 720 hours for month 09
# Tuzla: Saved 720 hours for month 09
